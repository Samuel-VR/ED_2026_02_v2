# %%
from goodrich.ch08.linked_binary_tree import*

# %%
L= LinkedBinaryTree()
root = L._add_root(10)
l=L._add_left(root, 8)
r=L._add_rigth(root, 20)

# %%
def find_min(T:LinkedBinaryTree):
    '''Retorna el contenedor donde se encuentra el minimo'''
    while

# %%
def find_max(T:LinkedBinaryTree)
    while

# %%
for i in  L.inorder()

# %%
I=L.inorder()

# %%
a=next(I)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=next(I)
#
# NameError: name 'I' is not defined

# %%
def es_ordenado(T:LinkedBinaryTree):
    I=T.inorder()
    a=next(T)
    for i in range(len(T)):
        b=next(T)
        if b.element(I)<a.element(I):
            return False
        a=next(T)
        a,b = b,a
    return True
