# %%
from goodrich.ch09.unsorted_priority_queue import*

# %%
PQ=UnsortedPriorityQueue()

# %%
PQ.add(2, "Mar")
PQ.add(3.5, "Car")

# %%
class Empty(Exception):
    pass
class StackPQ():
    def __init__(self):
        self._data = UnsortedPriorityQueue()
        self.key=0
    def push(self, e):
        self.data.add(self.key, e)
        self.key-=1
    def top(self):
        self.data.min()[1]
    def pop(self):
        if len(self._data) == 0:
            raise Empty('Stack is empty')
        self.data.remove_min()[1]
